# %% [markdown]
# <a href="https://colab.research.google.com/github/NwamamaAuch/DataWraggling/blob/main/HR_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas numpy seaborn matplot
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.2/769.2 kB 25.6 MB/s eta 0:00:00
# ...
#   Created wheel for SimpleWebSocketServer: filename=SimpleWebSocketServer-0.1.2-py3-none-any.whl size=9667 sha256=ace3a826fdc19d22e25f4298db78b46eaf9fddcd7d27fc0b8826766eedb766c7
#   Stored in directory: /root/.cache/pip/wheels/af/cb/9d/23ef01c9c26b978be6d29ed456d7348abd0e96b1563049bd63
# ...
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26303 sha256=2ad9749aa59f4ca99a908b108313f782e3663000d788b6df335cd5a62f47a34e
#   Stored in directory: /root/.cache/pip/wheels/7c/d0/9e/1f26ebb66d9e1732e4098bc5a6c2d91f6c9a529838f0284890
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib_inline
import seaborn as sns

# %%
df=pd.read_csv("/content/HRDataset.csv")

# %%
df.head(10)
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
# 5         Anderson, Linda    10002          0                0         0
# 6           Andreola, Colby  10194          0                0         0
# 7               Athwal, Sam  10062          0                4         1
# 8          Bachiochi, Linda  10114          0                0         0
# 9        Bacong, Alejandro   10250          0                2         1
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# ...

# %%
df.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %% [markdown]
# # **Cheking for null valures**

# %%
df.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Gender                          0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
df.dropna()
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# 10       Baczenski, Rachael    10252          1                1         0
# 11            Barbara, Thomas  10242          1                1         1
# ..                        ...    ...        ...              ...       ...
# 301             Wilber, Barry  10048          1                1         1
# 302             Wilkes, Annie  10204          0                2         0
# 303     Williams, Jacquelyn    10264          0                0         0
# 304        Winthrop, Jordan    10033          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
#
# ...

# %%
df.rename(columns={"FromDiversityJobFairID":"D_JobFairID"})
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  D_JobFairID  Salary  ...  \
# ...

# %% [markdown]
# ### Select the rows that earns less than 89290

# %%
df[df["Salary"]<59290]
# Out:
#             Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 4        Anderson, Carol   10069          0                2         0
# 5       Anderson, Linda    10002          0                0         0
# 8        Bachiochi, Linda  10114          0                0         0
# 9      Bacong, Alejandro   10250          0                2         1
# 10   Baczenski, Rachael    10252          1                1         0
# ..                    ...    ...        ...              ...       ...
# 300       Whittier, Scott  10072          0                0         1
# 301         Wilber, Barry  10048          1                1         1
# 302         Wilkes, Annie  10204          0                2         0
# 307    Ybarra, Catherine   10301          0                0         0
# 310         Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
train = df.drop(['Salary','EmpID','LastPerformanceReview_Date'], axis=1)
test = df['Salary']

# %%
x_train, x_test, y_train, y_test = train_test_split(train, test, test_size=0.2, random_state=2)

# %%
# This is the cell where you're using train_test_split
x_train, x_test, y_train, y_test = train_test_split(train, test, test_size=0.2, random_state=2)

# %% [markdown]
# # **Try to get the top Departments and the Correlletion** **bold text**

# %%
df['Department'].value_counts().head(10).plot(kind='bar', title='Top 10 Departments')
plt.xlabel('Department')
# Out:
# Text(0.5, 0, 'Department')

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Gender', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
df['PositionID'].plot(kind='hist', bins=20, title='Distribution of Hire Dates')
# Out:
# <Axes: title={'center': 'Distribution of Hire Dates'}, ylabel='Frequency'>

# %%
sns.scatterplot(x='PositionID', y='Salary', data=df)
# Out:
# <Axes: xlabel='PositionID', ylabel='Salary'>

# %%
sns.pairplot(df, vars = ['Salary','PositionID','MaritalStatusID','EmpID'])
plt.show()

# %%
df[['Salary','PositionID','MaritalStatusID','EmpID']].dropna().corr()
# Out:
#                    Salary  PositionID  MaritalStatusID     EmpID
# Salary           1.000000   -0.130563        -0.070291 -0.115319
# PositionID      -0.130563    1.000000         0.021923 -0.036488
# MaritalStatusID -0.070291    0.021923         1.000000 -0.043851
# EmpID           -0.115319   -0.036488        -0.043851  1.000000

# %%
sns.heatmap(df[['Salary','PositionID','MaritalStatusID','EmpID']].dropna().corr(), annot=True)
# Out:
# <Axes: >
